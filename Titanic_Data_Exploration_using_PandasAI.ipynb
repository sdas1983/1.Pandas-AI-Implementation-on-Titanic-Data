# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
min(df['Fare'])
# Out:
# 0.0

# %%
pip install pandasai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 53.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 63.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ...

# %%
import os
from pandasai import Agent
from pandasai.llm.openai import OpenAI

# %%
os.environ["PANDASAI_API_KEY"] = "$2a$10$da5JHpmeBJGMCvMuSLGSSe8Do.d7qetXZK/z4d1Yt64u4WOUG02XS"

# %%
agent = Agent(df)

# %%
agent.chat('maximum fare')
# Out:
# 'The maximum fare is 512.3292.'

# %%
agent.chat('minimum fare')
# Out:
# 0.0

# %%
agent.chat('maximum age')
# Out:
# 80.0

# %%
agent.chat('name of the person who has maximum age')
# Out:
# 'The person with the maximum age is Barkworth, Mr. Algernon Henry Wilson.'

# %%
agent.chat('number of person with maximum age')
# Out:
# 1

# %%
agent.chat('maximum fare of person with maximum age')
# Out:
# 30.0

# %%
agent.chat('list down the names of person with maximum fare')
# Out:
# '                  Ward, Miss. Anna\nCardeza, Mr. Thomas Drake Martinez\n            Lesurer, Mr. Gustave J'

# %%
agent.chat('person aho has the minimum age')
# Out:
# 'The person with the minimum age is Thomas, Master. Assad Alexander.'

# %%
agent.chat('List down the null values in each column')
# Out:
#              DataFrame 1
# PassengerId            0
# Survived               0
# Pclass                 0
# Name                   0
# Sex                    0
# Age                  177
# SibSp                  0
# Parch                  0
# Ticket                 0
# Fare                   0
# Cabin                687
# Embarked               2

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
agent.chat('Shape of the dataset')
# Out:
# 'Shape of the dataset: (891, 12)'

# %%
agent.chat('male and female count from sex column')
# Out:
#         Sex
# male    577
# female  314
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Sex'].plot(kind='hist', bins=20, title='Sex')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Sex'].plot(kind='line', figsize=(8, 4), title='Sex')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
agent.chat('plot a pie chart of the survived and not survived')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('plot a multiple bar chart of the survived gender wise, with different colour')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
agent.chat('plot a null value ')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('plot null value using heatmap')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
import seaborn as sns
sns.heatmap(df.isnull(),yticklabels=False, cmap='viridis')
# Out:
# <Axes: >

# %%
agent.chat('passengers travelling in first , second and third class')
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#    Pclass
# 3     491
# 1     216
# 2     184

# %%
agent.chat('passengers travelling in first , second and third class and display the result sorted')
# Out:
#    Pclass
# 1     216
# 2     184
# 3     491

# %%
agent.chat('horizontal chart for passenger class and label the bars')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('bar chart for passenger class and label the bars')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
sns.set_style('whitegrid')
sns.countplot(x='Survived', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
agent.chat('bar chart count plot for survived and label the bars')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
sns.countplot(x='SibSp', data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
agent.chat('bar chart of siblings showing count and label the bars')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
agent.chat('distribution chart for age')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
agent.chat('plot histogram for fare')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('plot histogram for fare in red colour')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
df['Fare'].hist(color='red')
# Out:
# <Axes: >

# %%
sns.boxplot(x='Pclass', y='Age', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
agent.chat('box plot of age and pclass')
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
agent.chat('box plot of age and pclass in blue color')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
agent.chat('box plot of fare')
# Out:
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
#     raise NoResultFoundError("No result returned")
# pandasai.exceptions.NoResultFoundError: No result returned
#
# WARNING:pandasai.helpers.logger:Failed to execute code retrying with a correction framework [retry number: 1]
# ERROR:pandasai.helpers.logger:Failed with error: Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 85, in execute
#     result = self.execute_code(code_to_run, code_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_execution.py", line 175, in execute_code
# ...

# %%
agent.chat('violin plot for survived with sex')
# Out:
# '/content/exports/charts/temp_chart.png'
